# %%
include("Mondrian.jl")
using Plots
pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
Θ = Axis_Aligned_Box([0 1; 0 1])
l,c = Mondrian_process(Θ, 1);
show_mondrian_split_2d(c,true)
# Out:
# /home/harvey/.local/lib/python2.7/site-packages/matplotlib/figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
